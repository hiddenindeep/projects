# %% [markdown]
# # 智谱 AI 大模型
#
# https://bigmodel.cn/dev/howuse/introduction
#
# https://bigmodel.cn/dev/howuse/model
#
#
# ## 语言模型
#
# | 模型               | 描述                                                       | 上下文 | 最大输出 |
# | :----------------- | :--------------------------------------------------------- | :----- | :------- |
# | GLM-4-Plus         | **高智能旗舰**: 性能全面提升，长文本和复杂任务能力显著增强 | 128K   | 4K       |
# | GLM-4-Air-250414   | **高性价比**：推理能力和价格之间最平衡的模型               | 128K   | 16K      |
# | GLM-4-Long         | **超长输入**：专为处理超长文本和记忆型任务设计             | 1M     | 4K       |
# | GLM-4-AirX         | **极速推理**：具有超快的推理速度和强大的推理效果           | 8K     | 4K       |
# | GLM-4-FlashX       | **高速低价**：Flash增强版本，超快推理速度                  | 128K   | 4K       |
# | GLM-4-Flash-250414 | **免费模型**：零成本调用语言模型。                         | 128K   | 16K      |

# %%
from zhipuai import ZhipuAI
client = ZhipuAI(api_key="484abc507fc442a5adb5a10cc2c22911.sLSh6UYtQDGuVRlk") # 填写您自己的APIKey
response = client.chat.completions.create(
    model="glm-4-plus",  # 填写需要调用的模型编码
    messages=[
        {"role": "system", "content": "你是一个乐于解答各种问题的助手，你的任务是为用户提供专业、准确、有见地的建议。"},
        {"role": "user", "content": "农夫需要把狼、羊和白菜都带过河，但每次只能带一样物品，而且狼和羊不能单独相处，羊和白菜也不能单独相处，问农夫该如何过河。"}
    ],
    stream=True
)
for chunk in response:
    print(chunk.choices[0].delta.content, end="")
# Out:
# 这是一个经典的逻辑谜题，通常称为“农夫过河”问题。以下是解决这个问题的步骤：
#
# 1. **第一次过河**：农夫带羊过河。
#    - 左岸：狼、白菜
#    - 右岸：羊
#
# 2. **返回**：农夫空手返回。
#    - 左岸：狼、白菜
#    - 右岸：羊
#
# 3. **第二次过河**：农夫带狼过河。
#    - 左岸：白菜
#    - 右岸：羊、狼
#
# 4. **返回**：农夫带羊回到左岸。
#    - 左岸：羊、白菜
#    - 右岸：狼
#
# 5. **第三次过河**：农夫带白菜过河。
#    - 左岸：羊
#    - 右岸：狼、白菜
#
# 6. **返回**：农夫空手返回。
#    - 左岸：羊
#    - 右岸：狼、白菜
#
# 7. **第四次过河**：农夫带羊过河。
#    - 左岸：空
#    - 右岸：狼、羊、白菜
#
# 通过以上步骤，农夫成功地将狼、羊和白菜都带过了河，且没有违反任何规则（狼和羊、羊和白菜没有单独相处）。
#
# 希望这个解答对你有帮助！如果有其他问题，欢迎继续提问。

# %% [markdown]
# ## 推理模型
#
# | 模型         | 描述                                                       | 上下文 | 最大输出 |
# | :----------- | :--------------------------------------------------------- | :----- | :------- |
# | GLM-Z1-Air   | **推理模型**: 具备强大推理能力，适用于需要深度推理的任务。 | 32K    | 32K      |
# | GLM-Z1-AirX  | **极速推理**：具有超快的推理速度（最快可达 200 Tokens/s）  | 32K    | 30K      |
# | GLM-Z1-Flash | **免费推理**：免费的推理API，零成本调用推理大模型          | 32K    | 32K      |

# %%
response = client.chat.completions.create(
    model="glm-z1-air",  # 填写需要调用的模型编码
    messages=[
        {"role": "system", "content": "你是一个乐于解答各种问题的助手，你的任务是为用户提供专业、准确、有见地的建议。"},
        {"role": "user", "content": "农夫需要把狼、羊和白菜都带过河，但每次只能带一样物品，而且狼和羊不能单独相处，羊和白菜也不能单独相处，问农夫该如何过河。"}
    ],
    stream=True
)
for chunk in response:
    print(chunk.choices[0].delta.content, end="")
# Out:
# <think>
# 嗯，用户问的是经典的农夫过河问题，我得仔细想想怎么解答。首先，这个问题应该是有标准解法的，但作为新手，我需要一步步理清楚逻辑。
#
# 首先，问题条件：农夫需要带狼、羊、白菜过河，每次只能带一样东西。关键点在于，狼和羊不能单独在一起，羊和白菜也不能单独在一起。那河的两岸都要满足这个条件，对吧？也就是说，当农夫不在的时候，同一岸如果有狼和羊，或者羊和白菜，就会出问题。
#
# 那可能的步骤是什么呢？首先，农民只能带一样东西过河，所以需要多次往返。我需要考虑每一步带什么，然后回来带剩下的，同时确保两岸的安全。
#
# 首先，可能的第一次带羊过去，因为如果带狼或者白菜，那另一岸剩下的羊和另一个物品就会有问题。比如，如果带狼过去，留下羊和白菜，那羊会吃白菜。所以第一次必须带羊过去。
#
# 然后，农民回来，这时候对岸有羊，原岸有狼和白菜。接下来农民需要带什么？这时候，如果带狼过去，那么原岸剩下白菜，对岸有羊和狼，但农民在船上，所以对岸有狼和羊，但农民还没到，所以这时候对岸会有问题？或者农民到达后，狼和羊会在对岸，但农民在，所以没问题？
#
# 或者可能应该先带羊过去，回来后带白菜或者狼。假设农民带羊过去，回来后带狼过去。这时候对岸有羊和狼，但农民在，所以没问题。然后农民需要把狼带回来，或者留下？这时候可能有问题，因为如果农民带狼到对岸，然后回来，原岸剩下白菜，对岸有狼和羊，这时候农民不在，狼和羊在一起，就会出问题。所以这样可能不行。
#
# 或者，农民带羊过去，回来后带白菜过去。这时候对岸有羊和白菜，但农民在，所以没问题。然后农民需要把羊带回来，这样原岸有羊和狼，但农民在，所以没问题。然后带狼过去，这时候对岸有狼和白菜，农民在，没问题。最后回来带羊。这样可能可行。
#
# 让我再仔细梳理一遍：
#
# 1. 农民带羊到对岸。原岸剩下狼和白菜，安全。对岸有羊。
# 2. 农民独自返回原岸。现在原岸有狼、白菜，农民在，对岸有羊。
# 3. 农民带白菜到对岸。原岸剩下狼，安全。对岸有羊和白菜，但农民在，所以没问题。
# 4. 农民带羊返回原岸。现在对岸有白菜，原岸有狼和羊，农民在，所以安全。
# 5. 农民带狼到对岸。原岸剩下羊，安全。对岸有狼和白菜，农民在，没问题。
# 6. 农民独自返回原岸，带羊过去。这样所有都过河了。
#
# ...

# %% [markdown]
# ## 多模态模型
#
# https://bigmodel.cn/dev/api/normal-model/glm-4v
#
# | 模型             | 描述                                                         | 上下文 |
# | :--------------- | :----------------------------------------------------------- | :----- |
# | GLM-4V-Plus-0111 | **图像/视频理解**：具备卓越的多模态理解能力，可同时处理最多5张图像，最长支持2h 视频内容理解 | 16K    |
# | GLM-4V           | **图像理解**：持单张图像理解，适用于复杂图像解析的场景       | 4K     |
# | GLM-4V-Flash     | **免费模型**：支持单张图像理解，适用于简单图像解析的场景     | 4K     |
#
# | 模型             | 描述                                                         | 多分辨率 |
# | :--------------- | :----------------------------------------------------------- | :------- |
# | CogVideoX-2      | **视频生成**：输入文本或图片即可轻松制作视频                 | 支持     |
# | CogVideoX-Flash  | **视频生成**：免费且好用的视频生成模型，具备强大的视频生成能力 | 支持     |
# | CogView-4-250304 | **图像生成**：具备较强的复杂语义对齐和指令跟随能力， 支持任意长度的中英双语输入，支持生成多种分辨率的图像， 同时具备较强的文字生成能力。 | 支持     |
# | CogView-4        | **图像生成**：生成符合指令且美学评分更高的图像               | 支持     |
# | CogView-3-Flash  | **免费模型**：免费的图像生成模型                             | 支持     |

# %%
response = client.chat.completions.create(
    model="glm-4v-flash",  # 填写需要调用的模型编码
    messages=[
        {"role": "user", "content": "你是一个乐于解答各种问题的助手，你的任务是为用户提供专业、准确、有见地的建议。"},
    ],
    stream=True
)
for chunk in response:
    print(chunk.choices[0].delta.content, end="")
# Out:
# 这张图片显示的是一张白纸上的黑色文字“我”。这个字是中文汉字，表示第一人称单数的主格代词，相当于英文中的“I”。
#
# 如果你有其他问题或需要帮助，请告诉我！

# %%
import base64
from PIL import Image

img_path = "./data/ai_challenger_caption_validation_20170910/caption_validation_images_20170910/0003a0755539c426ecfc7ed79bc74aeea6be740b.jpg"
with open(img_path, 'rb') as img_file:
    img_base = base64.b64encode(img_file.read()).decode('utf-8')

response = client.chat.completions.create(
    model="glm-4v-flash",  # 填写需要调用的模型编码
    messages=[
      {
        "role": "user",
        "content": [
          {
            "type": "image_url",
            "image_url": {
                "url": img_base
            }
          },
          {
            "type": "text",
            "text": "告诉我，小女孩在吃什么？"
          }
        ]
      }
    ],
    stream=True
)
for chunk in response:
    print(chunk.choices[0].delta.content, end="")
# Out:
# 小女孩正在吃一个橙子。

# %%
Image.open(img_path)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=550x668>

# %%
response = client.chat.completions.create(
    model="glm-4v-flash",  # 填写需要调用的模型编码
    messages=[
      {
        "role": "user",
        "content": [
          {
            "type": "image_url",
            "image_url": {
                "url": "http://mirror.coggle.club/image/cat.jpeg"
            }
          },
          {
            "type": "text",
            "text": "请描述这个图片"
          }
        ]
      }
    ],
    stream=True
)
for chunk in response:
    print(chunk.choices[0].delta.content, end="")
# Out:
# 这张照片中的猫咪是一只橘白相间的虎斑猫，它有着圆圆的大眼睛和粉色的鼻子，看起来非常可爱。它的身体大部分是白色的，脸部、耳朵和背部有棕黄色的条纹花纹。
#
# 这只猫咪正坐在一个室内环境中，背景模糊不清，但可以看出它可能在一个房间里。光线柔和，给整个场景增添了一种温馨的氛围。

# %%
response = client.images.generations(
    model="cogview-4-250304", #填写需要调用的模型编码
    prompt="一群踢足球的运动员。",
)

print(response.data[0].url)
# Out:
# https://aigc-files.bigmodel.cn/api/cogview/2025042509071383ab5ffa5bde41d4_0.png

# %%
response = client.videos.generations(
    model="cogvideox-2",
    prompt="比得兔开小汽车，游走在马路上，脸上的表情充满开心喜悦。",
    quality="quality",  # 输出模式，"quality"为质量优先，"speed"为速度优先
    with_audio=True,
    size="1920x1080",  # 视频分辨率，支持最高4K（如: "3840x2160"）
    fps=30,  # 帧率，可选为30或60
)
print(response)
# Out:
# VideoObject(id='83801705482876378-8769655676140804996', model='cogvideox-2', video_result=None, task_status='PROCESSING', request_id='2025042315231578a70f38ae1940fb')

# %%
response = client.videos.retrieve_videos_result(
    id="83801705482876378-8769655676140804996"
)
print(response)
# Out:
# VideoObject(id=None, model='cogvideox-2', video_result=[VideoResult(url='https://aigc-files.bigmodel.cn/api/cogvideo/d2ae20d4-2013-11f0-9198-fef226b85e0b_0.mp4', cover_image_url='https://aigc-files.bigmodel.cn/api/cogvideo/d2ae20d4-2013-11f0-9198-fef226b85e0b_cover_0.jpeg')], task_status='SUCCESS', request_id='2025042315231578a70f38ae1940fb')

# %%
image_url = "http://mirror.coggle.club/image/cat.jpeg"  # 替换为您的图片URL地址

# 调用视频生成接口
response = client.videos.generations(
    model="cogvideox-2",  # 使用的视频生成模型
    image_url=image_url,  # 提供的图片URL地址或者 Base64 编码
    prompt="让画面动起来",  
    quality="quality",  # 输出模式，"quality"为质量优先，"speed"为速度优先
    with_audio=True,
    size="1920x1080",  # 视频分辨率，支持最高4K（如: "3840x2160"）
    fps=30,  # 帧率，可选为30或60
)

# 打印返回结果
print(response)
# Out:
# VideoObject(id='83801705482876378-8769661586016647514', model='cogvideox-2', video_result=None, task_status='PROCESSING', request_id='20250423152409e215d9ed6ce64a8e')

# %%
response = client.videos.retrieve_videos_result(
    id="83801705482876378-8769661586016647514"
)
print(response)
# Out:
# VideoObject(id=None, model='cogvideox-2', video_result=[VideoResult(url='https://aigc-files.bigmodel.cn/api/cogvideo/f2542ef6-2013-11f0-89cc-c2b4694f5cad_0.mp4', cover_image_url='https://aigc-files.bigmodel.cn/api/cogvideo/f2542ef6-2013-11f0-89cc-c2b4694f5cad_cover_0.jpeg')], task_status='SUCCESS', request_id='20250423152409e215d9ed6ce64a8e')

# %% [markdown]
# ## 实时音视频
#
# | 模型         | 描述                                                         | 上下文 | 最大输出 |
# | :----------- | :----------------------------------------------------------- | :----- | :------- |
# | GLM-Realtime | **实时视频通话**: 具有跨文本、音频和视频进行实时推理的能力，进行流畅的通话 | 8K     | 1K       |
# | GLM-4-Voice  | **端到端语音模型**: GLM-4-Voice 能够直接理解和生成中英文语音，进行实时语音对话 | 8K     | 4K       |
#
# ## 向量模型
#
# | 模型        | 描述                                  | 最大输入 | 向量维度 |
# | :---------- | :------------------------------------ | :------- | :------- |
# | Embedding-3 | **最新模型**：支持自定义向量维度      | 8K       | 2048     |
# | Embedding-2 | **旧版模型**：目前已被Embedding-3取代 | 8K       | 1024     |
#
# ## 其他模型
#
# | 模型       | 描述                                                         | 上下文 | 最大输出 |
# | :--------- | :----------------------------------------------------------- | :----- | :------- |
# | CharGLM-4  | **拟人模型**：适用于情感陪伴和虚拟角色                       | 8K     | 4K       |
# | Emohaa     | **心理模型**：具备专业咨询能力，帮助用户理解情感并应对情绪问题 | 8K     | 4k       |
# | CodeGeeX-4 | **代码模型**：适用于代码自动补全任务                         | 128K   | 32k      |
# | Rerank     | **重排序模型**：计算文本之间的 score 值，对召回结果进行重排序 | 4K     | -        |

# %% [markdown]
# # GPT

# %%
import requests
import json

url = "https://openkey.cloud/v1/chat/completions"

headers = {
  'Content-Type': 'application/json',
  'Authorization': 'Bearer sk-WkCbMVOViwqUVVdD97E9E88612A14071A40213E24c2989Ab'
}

data = {
  "model": "gpt-3.5-turbo",
  "messages": [{"role": "user", "content": "你好呀"}]
}

response = requests.post(url, headers=headers, json=data)

print("Status Code", response.status_code)
print("JSON Response ", response.json())
# Out:
# Status Code 200
# JSON Response  {'choices': [{'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}, 'finish_reason': 'stop', 'index': 0, 'logprobs': None, 'message': {'content': '你好，请问有什么可以帮助你的吗？', 'role': 'assistant'}}], 'created': 1745543450, 'id': 'chatcmpl-BQ1sYb1gmelP23xNBnKLtvhk7dLKR', 'model': 'gpt-3.5-turbo-0125', 'object': 'chat.completion', 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'system_fingerprint': 'fp_0165350fbb', 'usage': {'completion_tokens': 18, 'prompt_tokens': 11, 'total_tokens': 29}}

# %%
url = 'https://openkey.cloud/v1/images/generations'

# 请求的数据
payload = {
    "model": "dall-e-3",
    'prompt': '想象一个充满活力的科幻世界，这里是“牛爷爷的彩色星球”。中心是一个仁慈、智慧的牛爷爷形象，他的外观类似于传统的中国智者，身穿宇航服，周围环绕着五颜六色的星球和星云。这些星球光彩夺目，各具特色，有的覆盖着翠绿的森林，有的环绕着蓝色的海洋，还有的散发着神秘的紫色光芒。海报的背景是深邃的宇宙，点缀着繁星和迷人的星云。整个画面应该流露出一种未来科技与自然和谐共存的感觉，充满神秘和梦幻的氛围。牛爷爷的面容慈祥，目光深邃，仿佛在诉说着宇宙的奥秘和生命的多彩。',
    'n': 1,
    'quality': "hd",
    'size': '1792x1024'  # 修改这里
}

# 发送POST请求
response = requests.post(url, headers=headers, data=json.dumps(payload))

# 打印响应结果
print(response.json())
# Out:
# {'created': 1745543453, 'data': [{'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}, 'prompt_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'profanity': {'detected': False, 'filtered': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}, 'revised_prompt': "Imagine a vibrant sci-fi world, referred to as 'Colorful Planet of the Wise Bull'. At the center is a figure resembling a traditional Chinese sage in the form of a kind and wise bull, dressed in a spacesuit, surrounded by a galaxy of colorful, diverse planets and nebulae. Some of these planets sparkle exceptionally - some blanketed with lush green forests, some enveloped by blue oceans, others radiating mysterious purpl
# ...

# %%
url = "https://openkey.cloud/v1/audio/speech"
input_text = "《三国演义》以东汉末年三国时期为背景，展现了刘备、关羽、张飞等英雄豪杰的壮丽故事。他们桃园结义，共同抵抗董卓、曹操等反动势力，最终形成了三足鼎立的局面。小说描写了忠义仁爱、智勇双全的形象，同时也展现了权谋斗争和人性的复杂性。《三国演义》是一部具有高历史价值和文学艺术价值的作品，塑造了许多永垂史册的英雄形象，对中国传统文化产生了深远影响。"
query = {
            "model":"tts-1-hd",
            "input":input_text,
            "voice":"alloy",
            "response_format":"mp3",
            "speed":1,
        }
response = requests.post(url=url, data=json.dumps(query), headers=headers)
# 保存文件
f = open("./tts-1-hd.mp3", "wb")
f.write(response.content)
f.close()
